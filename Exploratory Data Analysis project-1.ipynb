# %%
from warnings import filterwarnings
filterwarnings("ignore")

# %%
from pandas import read_csv
A = read_csv("C:/Users/pritam hakande/Downloads/50_startups.csv")

# %% [markdown]
# # Drop a row i a dataframe

# %%
A.drop(index = 2,axis=0)
# Out:
#           RND      ADMIN        MKT       STATE     PROFIT
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# 15  114523.61  122616.84  261776.23    New York  129917.04
# ...

# %%
from seaborn import boxplot,scatterplot
from matplotlib.pyplot import plot,subplot,figure
m = 1
figure(figsize=(15,15))
for i in A.columns:
    if(A[i].dtypes == "object"):
        subplot(3,2,m)
        boxplot(A[i],A.PROFIT)
        m = m + 1
    else:
        subplot(3,2,m)
        scatterplot(A[i],A.PROFIT)
        m = m + 1

# %%
from pandas import read_csv
A = read_csv("C:/Users/Pritam hakande/Downloads/cars93.csv")

# %%
import pandas
A = pandas.read_csv("C:/Users/pritam hakande/Downloads/cars93.csv")

# %%
import pandas as pd
A = pd.read_csv("C:/Users/pritam hakande/Downloads/cars93.csv")

# %%
A.head()
# Out:
#    id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0   1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1   2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2   3         Audi       90  Compact       25.9   29.1       32.3        20
# 3   4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4   5          BMW     535i  Midsize       23.7   30.0       36.2        22
#
#    MPG.highway             AirBags  ... Passengers Length  Wheelbase  Width  \
# 0           31                None  ...          5    177        102     68
# 1           25  Driver & Passenger  ...          5    195        115     71
# 2           26         Driver only  ...          5    180        102     67
# 3           26                 NaN  ...          6    193        106     70
# 4           30         Driver only  ...          4    186        109     69
#
# ...

# %% [markdown]
# # Univariate analaysis

# %% [markdown]
# univariate analysis means analysing in a single columns

# %%
from seaborn import distplot
distplot(A.Length)
# Out:
# <AxesSubplot:xlabel='Length', ylabel='Density'>

# %%
A.Length.hist()
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt

# %%
from matplotlib.pyplot import plot

# %%
from seaborn import distplot
distplot(A.Length)
# Out:
# <AxesSubplot:xlabel='Length', ylabel='Density'>

# %%
import seaborn
seaborn.distplot(A.Length)
# Out:
# <AxesSubplot:xlabel='Length', ylabel='Density'>

# %% [markdown]
# # Continous columns
# (AGE,SALARY,HEIGHT,WEIGHT)

# %% [markdown]
# 1.Distribution plot
# 2.Histogram

# %%
import seaborn as sb
sb.distplot(A.Length)
# Out:
# <AxesSubplot:xlabel='Length', ylabel='Density'>

# %%
A.Length.hist()
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
A = pd.read_csv("C:/Users/pritam hakande/Downloads/cars93.csv")

# %%
Y = A[["Price"]]
X = A.drop(labels=["id","Make","Model","Price","Min.Price","Max.Price"],axis=1)
from seaborn import boxplot,scatterplot
from matplotlib.pyplot import plot,subplot,figure
x = 1
figure(figsize=(30,30))
for i in X.columns:
    if(X[i].dtypes == "object"):
        subplot(8,3,x)
        boxplot(X[i],Y.Price)
        x = x + 1
    else:
        subplot(8,3,x)
        scatterplot(X[i],Y.Price)
        x = x + 1

# %%
A = A.drop(labels=["id","Make","Model"],axis=1)

# %%
A.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Manufacturer        93 non-null     object
#  1   Type                93 non-null     object
#  2   Min.Price           93 non-null     float64
#  3   Price               93 non-null     float64
#  4   Max.Price           93 non-null     float64
#  5   MPG.city            93 non-null     int64
#  6   MPG.highway         93 non-null     int64
#  7   AirBags             89 non-null     object
#  8   DriveTrain          93 non-null     object
#  9   Cylinders           93 non-null     object
#  10  EngineSize          93 non-null     float64
#  11  Horsepower          93 non-null     int64
#  12  RPM                 93 non-null     int64
#  13  Rev.per.mile        93 non-null     int64
#  14  Man.trans.avail     93 non-null     object
# ...

# %%
cat = []
con = []
for i in A.columns:
    if(A[i].dtypes == "object"):
        cat.append(i)
    else:
        con.append(i)

# %%
con
# Out:
# ['Min.Price',
#  'Price',
#  'Max.Price',
#  'MPG.city',
#  'MPG.highway',
#  'EngineSize',
#  'Horsepower',
#  'RPM',
#  'Rev.per.mile',
#  'Fuel.tank.capacity',
#  'Passengers',
#  'Length',
#  'Wheelbase',
#  'Width',
#  'Turn.circle',
#  'Rear.seat.room',
#  'Luggage.room',
#  'Weight']

# %%
cat
# Out:
# ['Manufacturer',
#  'Type',
#  'AirBags',
#  'DriveTrain',
#  'Cylinders',
#  'Man.trans.avail',
#  'Origin']

# %% [markdown]
# # Bivariate analysis

# %% [markdown]
# cat vs con (boxplot)

# %%
B = A[["Type","Price"]]

# %%
from seaborn import boxplot
boxplot(B.Type,B.Price)
# Out:
# <AxesSubplot:xlabel='Type', ylabel='Price'>

# %%
boxplot(B.Type,B.Price,whis=1.7)
# Out:
# <AxesSubplot:xlabel='Type', ylabel='Price'>

# %%
boxplot(B.Type,B.Price,whis=5)
# Out:
# <AxesSubplot:xlabel='Type', ylabel='Price'>

# %% [markdown]
# # create distribution plots for all continous columns

# %% [markdown]
# 3 plots in a row

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
plt.subplot(2,3,1)
distplot(A['Min.Price'])
plt.subplot(2,3,2)
distplot(A['Price'])
plt.subplot(2,3,3)
distplot(A['Max.Price'])
plt.subplot(2,3,4)
distplot(A['MPG.city'])
plt.subplot(2,3,5)
distplot(A['MPG.highway'])
plt.subplot(2,3,6)
distplot(A['EngineSize'])
# Out:
# <AxesSubplot:xlabel='EngineSize', ylabel='Density'>

# %%
nrows = len(con)/3
nrows
# Out:
# 6.0

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
plt.figure(figsize=(21,28))
w = 1
for i in con:
    plt.subplot(nrows,3,w)
    distplot(A[i])
    w = w + 1

# %% [markdown]
# # univariate analysis

# %% [markdown]
# catgorical columns
#
# 1.countplot
# 2.countplot(horizontal)
# 3.pie chart

# %%
import pandas as pd 
A = pd.read_csv("C:/Users/pritam hakande/Downloads/cars93.csv")

A = A.drop(labels=["id","Make","Model"],axis=1)
cat = []
con = []
for i in A.columns:
    if(A[i].dtypes == "object"):
        cat.append(i)
    else:
        con.append(i)

# %%
A.AirBags.value_counts()
# Out:
# Driver only           42
# None                  33
# Driver & Passenger    14
# Name: AirBags, dtype: int64

# %%
A.AirBags.value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
A.AirBags.value_counts().plot(kind="barh")
# Out:
# <AxesSubplot:>

# %%
A.AirBags.value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='AirBags'>

# %%
nrows = round(len(cat)/3,0)+1

# %%
cat
# Out:
# ['Manufacturer',
#  'Type',
#  'AirBags',
#  'DriveTrain',
#  'Cylinders',
#  'Man.trans.avail',
#  'Origin']

# %%
plt.figure(figsize=(20,20))
w = 1
for i in cat:
    plt.subplot(nrows,3,w)
    A[i].value_counts().plot(kind="pie")
    w = w + 1

# %%
plt.figure(figsize=(20,20))
w = 1
for i in cat:
    plt.subplot(nrows,3,w)
    A[i].value_counts().plot(kind="barh")
    w = w + 1

# %%
plt.figure(figsize=(20,20))
w = 1
for i in cat:
    plt.subplot(nrows,3,w)
    A[i].value_counts().plot(kind="bar")
    w = w + 1

# %% [markdown]
# # Bivariate anlysis

# %% [markdown]
# 1.con vs con(scatterplot)

# %%
from seaborn import scatterplot
scatterplot(A['Price'],A['MPG.city'])
# Out:
# <AxesSubplot:xlabel='Price', ylabel='MPG.city'>

# %%
B = pd.read_csv("C:/Users/pritam hakande/Downloads/50_startups.csv")
from seaborn import scatterplot
scatterplot(B.RND,B.PROFIT)
# Out:
# <AxesSubplot:xlabel='RND', ylabel='PROFIT'>

# %%
from matplotlib.pyplot import scatter,plot,xlabel,ylabel,title,xticks,yticks
scatter (B.RND,B.PROFIT,c="orange",marker="p")
xlabel("Amount invested in RND")
ylabel("Amount of PROFIT occurred")
title("scatterplot of RND vs PROFIT")
# Out:
# Text(0.5, 1.0, 'scatterplot of RND vs PROFIT')
